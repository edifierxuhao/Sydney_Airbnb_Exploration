# %% [markdown]
# # Sydney Airbnb Data Exploration
# ## by Hao Xu
#
# ## Preliminary Wrangling
#
#
# This document explores **Sydney Airbnb Dataset**.

# %%
# import all packages and set plots to be embedded inline
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import geopandas as gpd
import descartes
from shapely.geometry import Point, Polygon
import re
from collections import Counter
from nltk.corpus import stopwords

# %matplotlib inline
# Out:
# (36662, 16)
#       id                                               name  host_id  \
# 0  12351                  Sydney City & Harbour at the door    17061
# 1  14250                                Manly Harbour House    55948
# 2  15253  Stunning Penthouse Apartment In Heart Of The City    59850
# 3  20865                 3 BED HOUSE + 1 BED STUDIO Balmain    64282
# 4  26174                 COZY PRIVATE ROOM, GREAT LOCATION!   110561
#
#   host_name  neighbourhood_group neighbourhood   latitude   longitude  \
# 0    Stuart                  NaN        Sydney -33.865153  151.191896
# 1     Heidi                  NaN         Manly -33.800929  151.261722
# 2     Morag                  NaN        Sydney -33.880455  151.216541
# 3     Fiona                  NaN    Leichhardt -33.859072  151.172753
# 4    Amanda                  NaN     Woollahra -33.889087  151.259404
#
#          room_type  price  minimum_nights  number_of_reviews last_review  \
# 0     Private room    100               2                493  2018-11-21
# 1  Entire home/apt    471               5                  1  2016-01-02
# 2     Private room    109               2                300  2018-11-16
# 3  Entire home/apt    450               7                 15  2018-01-07
# 4     Private room     62               1                 42  2018-11-23
#
#    reviews_per_month  calculated_host_listings_count  availability_365
# 0               4.83                               2               187
# 1               0.03                               2               321
# 2               3.63                               2               316
# 3               0.18                               1                69
# 4               0.45                               1               140

# %%
# load the listing summary dataset
sl_df = pd.read_csv('sydney_listings_summary_dec18.csv')
print(sl_df.shape)
sl_df.head()

# %% [markdown]
# There are 23439 Airbnb was owned

# %%
sl_df.neighbourhood.value_counts().index
# Out:
# Index(['Sydney', 'Waverley', 'Randwick', 'Manly', 'Warringah', 'Woollahra',
#        'North Sydney', 'Marrickville', 'Pittwater', 'Leichhardt', 'Rockdale',
#        'Botany Bay', 'Ryde', 'Mosman', 'Parramatta', 'Willoughby', 'Auburn',
#        'Sutherland Shire', 'Canada Bay', 'Hornsby', 'Ku-Ring-Gai',
#        'Canterbury', 'Ashfield', 'Lane Cove', 'The Hills Shire', 'Burwood',
#        'Blacktown', 'Hurstville', 'Bankstown', 'City Of Kogarah',
#        'Strathfield', 'Penrith', 'Holroyd', 'Liverpool', 'Campbelltown',
#        'Fairfield', 'Hunters Hill', 'Camden'],
#       dtype='object')

# %%
import geopandas as gpd
import descartes
from shapely.geometry import Point, Polygon

# %%
aus_poas = gpd.read_file('aus_poas.shp')

# %%
ax = aus_poas.plot()

# %%
syd_post = pd.read_csv('sydney_postcode.csv')
syd_post[syd_post['City/ Town/ Suburb'] == 'Ku Ring Gai']
# Out:
# Empty DataFrame
# Columns: [Postcode, District, City/ Town/ Suburb]
# Index: []

# %%
syd_post = pd.read_csv('sydney_postcode.csv')
def get_code(suburb):
    syd_post[suburb in syd_post['City/ Town/ Suburb']]['Postcode']

# %%
syd_post.query('"Warringah" in City/ Town/ Suburb')['Warringah' in syd_post['City/ Town/ Suburb']]['Postcode']
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~/opt/anaconda3/lib/python3.7/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    2645             try:
# -> 2646                 return self._engine.get_loc(key)
#    2647             except KeyError:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: False
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-184-e194bdb222ee> in <module>
# ----> 1 syd_post['Warringah' in syd_post['City/ Town/ Suburb']]['Postcode']
#
# ~/opt/anaconda3/lib/python3.7/site-packages/pandas/core/frame.py in __getitem__(self, key)
#    2798             if self.columns.nlevels > 1:
#    2799                 return self._getitem_multilevel(key)
# -> 2800             indexer = self.columns.get_loc(key)
#    2801             if is_integer(indexer):
#    2802                 indexer = [indexer]
#
# ~/opt/anaconda3/lib/python3.7/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    2646                 return self._engine.get_loc(key)
#    2647             except KeyError:
# -> 2648                 return self._engine.get_loc(self._maybe_cast_indexer(key))
#    2649         indexer = self.get_indexer([key], method=method, tolerance=tolerance)
#    2650         if indexer.ndim > 1 or indexer.size > 1:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: False

# %%
a = list(sl_df.neighbourhood.value_counts().index)
a
# Out:
# ['Sydney',
#  'Waverley',
#  'Randwick',
#  'Manly',
#  'Warringah',
#  'Woollahra',
#  'North Sydney',
#  'Marrickville',
#  'Pittwater',
#  'Leichhardt',
#  'Rockdale',
#  'Botany Bay',
#  'Ryde',
#  'Mosman',
#  'Parramatta',
#  'Willoughby',
#  'Auburn',
#  'Sutherland Shire',
#  'Canada Bay',
#  'Hornsby',
#  'Ku-Ring-Gai',
#  'Canterbury',
#  'Ashfield',
#  'Lane Cove',
#  'The Hills Shire',
#  'Burwood',
#  'Blacktown',
#  'Hurstville',
#  'Bankstown',
#  'City Of Kogarah',
#  'Strathfield',
#  'Penrith',
#  'Holroyd',
#  'Liverpool',
#  'Campbelltown',
#  'Fairfield',
#  'Hunters Hill',
#  'Camden']

# %%
list = []
for i in a:
    j = str.lower(i)
    print(j)
# Out:
# sydney
# waverley
# randwick
# manly
# warringah
# woollahra
# north sydney
# marrickville
# pittwater
# leichhardt
# rockdale
# botany bay
# ryde
# mosman
# parramatta
# willoughby
# auburn
# sutherland shire
# canada bay
# hornsby
# ku-ring-gai
# canterbury
# ashfield
# lane cove
# the hills shire
# burwood
# blacktown
# hurstville
# bankstown
# city of kogarah
# strathfield
# penrith
# holroyd
# liverpool
# campbelltown
# fairfield
# hunters hill
# camden

# %%
[2024,

# %%
post_list = syd_post[syd_post['District'] == 'Sydney']['Postcode'].values
post_list
# Out:
# array([2000, 2001, 2002, 2004, 2006, 2007, 2008, 2009, 2010, 2011, 2012,
#        2015, 2016, 2017, 2018, 2019, 2020, 2021, 2022, 2023, 2024, 2025,
#        2026, 2027, 2028, 2029, 2030, 2031, 2032, 2033, 2034, 2035, 2036,
#        2037, 2038, 2039, 2040, 2041, 2042, 2043, 2044, 2045, 2046, 2047,
#        2048, 2049, 2050, 2052, 2057, 2059, 2060, 2061, 2062, 2063, 2064,
#        2065, 2066, 2067, 2068, 2069, 2070, 2071, 2072, 2074, 2075, 2076,
#        2086, 2087, 2088, 2089, 2090, 2092, 2093, 2094, 2095, 2096, 2100,
#        2109, 2110, 2111, 2112, 2113, 2114, 2115, 2116, 2117, 2118, 2119,
#        2120, 2121, 2122, 2123, 2124, 2125, 2126, 2127, 2128, 2129, 2130,
#        2131, 2132, 2133, 2134, 2135, 2136, 2137, 2138, 2139, 2140, 2141,
#        2142, 2143, 2144, 2145, 2146, 2147, 2148, 2150, 2151, 2152, 2153,
#        2154, 2155, 2156, 2158, 2160, 2161, 2162, 2163, 2164, 2165, 2166,
#        2167, 2168, 2170, 2171, 2172, 2173, 2174, 2175, 2176, 2177, 2178,
#        2179, 2190, 2191, 2192, 2193, 2194, 2195, 2196, 2197, 2198, 2199,
#        2200, 2203, 2204, 2205, 2206, 2207, 2208, 2209, 2210, 2211, 2212,
#        2213, 2214, 2216, 2217, 2218, 2219, 2220, 2221, 2222, 2223, 2224,
#        2225, 2226, 2227, 2228, 2229, 2230, 2231, 2232, 2233, 2234, 2500,
#        2502, 2505, 2506, 2508, 2515, 2516, 2517, 2518, 2519, 2520, 2521,
#        2522, 2525, 2526, 2555, 2556, 2557, 2558, 2559, 2560, 2563, 2564,
#        2565, 2566, 2567, 2568, 2569, 2570, 2571, 2572, 2573, 2745, 2747,
#        2748, 2749, 2750, 2751, 2752, 2753, 2754, 2757, 2758, 2759, 2760,
#        2761, 2762, 2763, 2765, 2766, 2767, 2768, 2769, 2770, 2773, 2774,
#        2776, 2777, 2778, 2779, 2782, 2783, 2784, 2785])

# %%
geometry = [Point(xy) for xy in zip(sl_df['longitude'],sl_df['latitude'])]
crs = {'init':'epsg:4326'}
geometry[:3]
# Out:
# [<shapely.geometry.point.Point at 0x135274b50>,
#  <shapely.geometry.point.Point at 0x135274550>,
#  <shapely.geometry.point.Point at 0x1352745d0>]

# %%
sl_df.head(1)
# Out:
#       id                               name  host_id host_name  \
# 0  12351  Sydney City & Harbour at the door    17061    Stuart
#
#    neighbourhood_group neighbourhood   latitude   longitude     room_type  \
# 0                  NaN        Sydney -33.865153  151.191896  Private room
#
#    price  minimum_nights  number_of_reviews last_review  reviews_per_month  \
# 0    100               2                493  2018-11-21               4.83
#
#    calculated_host_listings_count  availability_365                 geometry
# 0                               2               187  POINT (-33.865 151.192)

# %%
sl_df.longitude
# Out:
# 0        151.191896
# 1        151.261722
# 2        151.216541
# 3        151.172753
# 4        151.259404
#             ...
# 36657    151.259375
# 36658    151.149573
# 36659    151.081721
# 36660    151.150659
# 36661    151.211255
# Name: longitude, Length: 36662, dtype: float64

# %%
geo_df = gpd.GeoDataFrame(sl_df,crs = crs, geometry = geometry)
geo_df.head()
# Out:
#       id                                               name  host_id  \
# 0  12351                  Sydney City & Harbour at the door    17061
# 1  14250                                Manly Harbour House    55948
# 2  15253  Stunning Penthouse Apartment In Heart Of The City    59850
# 3  20865                 3 BED HOUSE + 1 BED STUDIO Balmain    64282
# 4  26174                 COZY PRIVATE ROOM, GREAT LOCATION!   110561
#
#   host_name  neighbourhood_group neighbourhood   latitude   longitude  \
# 0    Stuart                  NaN        Sydney -33.865153  151.191896
# 1     Heidi                  NaN         Manly -33.800929  151.261722
# 2     Morag                  NaN        Sydney -33.880455  151.216541
# 3     Fiona                  NaN    Leichhardt -33.859072  151.172753
# 4    Amanda                  NaN     Woollahra -33.889087  151.259404
#
#          room_type  price  minimum_nights  number_of_reviews last_review  \
# 0     Private room    100               2                493  2018-11-21
# 1  Entire home/apt    471               5                  1  2016-01-02
# 2     Private room    109               2                300  2018-11-16
# 3  Entire home/apt    450               7                 15  2018-01-07
# 4     Private room     62               1                 42  2018-11-23
#
#    reviews_per_month  calculated_host_listings_count  availability_365  \
# 0               4.83                               2               187
# 1               0.03                               2               321
# 2               3.63                               2               316
# 3               0.18                               1                69
# 4               0.45                               1               140
#
#                       geometry
# 0  POINT (151.19190 -33.86515)
# 1  POINT (151.26172 -33.80093)
# 2  POINT (151.21654 -33.88045)
# 3  POINT (151.17275 -33.85907)
# 4  POINT (151.25940 -33.88909)

# %%
geo_df.room_type.value_counts()
# Out:
# Entire home/apt    22918
# Private room       13115
# Shared room          629
# Name: room_type, dtype: int64

# %%
fig,ax = plt.subplots(figsize = (15,15))
syd_poas.plot(ax = ax, alpha = 0.3, color = 'grey')
plt.scatter(data = geo_df[geo_df['room_type'] == 'Private room'], x = 'longitude', y = 'latitude',s = 1,alpha= 0.5)
plt.scatter(data = geo_df[geo_df['room_type'] == 'Entire home/apt'], x = 'longitude', y = 'latitude', c= 'red',s = 1,alpha= 0.5)
plt.scatter(data = geo_df[geo_df['room_type'] == 'Shared room'], x = 'longitude', y = 'latitude', c= 'green',s = 1)

# %%
syd_poas = aus_poas.query('code >= 2000 & code <= 2200 | code in @post_list & (code < 2500 | code >= 2555 & code <= 2770 & code != 2758)|code == 2756 ')
fig,ax = plt.subplots(figsize = (8,8))
syd_poas.plot(ax = ax);

# %%
fig,ax = plt.subplots(figsize = (15,15))
syd_poas.plot(ax = ax, alpha = 0.4, color = 'grey')
geo_df[geo_df['room_type'] == 'Entire home/apt'].plot(ax=ax, color = 'red', marker = '^', label = '1', alpha = 0.01)

;
# Out:
# ''

# %%
a = sl_df.host_id.value_counts().reset_index().copy()
b = list(a[a.host_id>1]['index'].values)

# %%
sl_df.query('host_id in @b').availability_365.mean()
# Out:
# 133.32412801694787

# %%
sl_df.query('not host_id in @b').availability_365.mean()
# Out:
# 77.12855619535082

# %%
len(sl_df.host_id.value_counts().values)
# Out:
# 27219

# %%
sr_df = pd.read_csv('sydney_reviews_summary_dec18.csv')
sr_df.head()
# Out:
#    listing_id        date
# 0       12351  2010-07-24
# 1       12351  2010-08-09
# 2       12351  2010-08-23
# 3       12351  2010-09-06
# 4       12351  2010-09-20

# %%
sc_df = pd.read_csv('sydney_calendar_dec18.csv')
sc_df.head()
# Out:
#    listing_id        date available    price
# 0       14250  2019-12-06         t  $470.00
# 1       12351  2019-08-17         t  $110.00
# 2       12351  2019-08-16         t  $110.00
# 3       12351  2019-08-15         t  $110.00
# 4       12351  2019-08-14         t  $110.00

# %%
print(sl_df.shape)
print(sr_df.shape)
print(sc_df.shape)
# Out:
# (36662, 16)
# (446708, 2)
# (13381265, 4)

# %%
sc_df.listing_id.value_counts()
# Out:
# 29779763    365
# 21529503    365
# 813853      365
# 822017      365
# 18196517    365
#            ...
# 10176060    365
# 24550278    365
# 21904530    365
# 21830902    365
# 409800      365
# Name: listing_id, Length: 36661, dtype: int64

# %%
sc_df[sc_df['listing_id'] == 12351]
# Out:
#      listing_id        date available    price
# 1         12351  2019-08-17         t  $110.00
# 2         12351  2019-08-16         t  $110.00
# 3         12351  2019-08-15         t  $110.00
# 4         12351  2019-08-14         t  $110.00
# 5         12351  2019-08-13         t  $110.00
# ..          ...         ...       ...      ...
# 361       12351  2018-12-11         f      NaN
# 362       12351  2018-12-10         f      NaN
# 363       12351  2018-12-09         f      NaN
# 364       12351  2018-12-08         f      NaN
# 365       12351  2018-12-07         f      NaN
#
# [365 rows x 4 columns]

# %%
sl_df["name"] = sl_df["name"].astype(str)

# %%
import re
from collections import Counter
from nltk.corpus import stopwords

sw = stopwords.words('english')

r = re.compile('[a-z]+')

a = r.findall(" ".join(sl_df["name"]).lower())
b = [i for i in a if i not in sw]

Counter(b).most_common(100)
# Out:
# [('apartment', 7766),
#  ('beach', 6321),
#  ('room', 5909),
#  ('bedroom', 4213),
#  ('bondi', 3544),
#  ('sydney', 3360),
#  ('home', 3215),
#  ('house', 2977),
#  ('private', 2972),
#  ('city', 2421),
#  ('modern', 2213),
#  ('close', 1981),
#  ('spacious', 1872),
#  ('views', 1819),
#  ('location', 1763),
#  ('bed', 1676),
#  ('cbd', 1673),
#  ('studio', 1657),
#  ('near', 1528),
#  ('family', 1365),
#  ('view', 1312),
#  ('beautiful', 1309),
#  ('manly', 1269),
#  ('sunny', 1205),
#  ('harbour', 1190),
#  ('large', 1186),
#  ('heart', 1175),
#  ('apt', 1093),
#  ('bright', 1083),
#  ('double', 1052),
#  ('new', 1051),
#  ('terrace', 996),
#  ('cosy', 975),
#  ('luxury', 946),
#  ('central', 904),
#  ('great', 882),
#  ('pool', 875),
#  ('walk', 843),
#  ('br', 742),
#  ('parking', 729),
#  ('cozy', 727),
#  ('quiet', 727),
#  ('garden', 727),
#  ('hills', 722),
#  ('stylish', 715),
#  ('coogee', 707),
#  ('surry', 687),
#  ('one', 685),
#  ('park', 681),
#  ('unit', 650),
#  ('balcony', 649),
#  ('bathroom', 639),
#  ('min', 630),
#  ('airport', 630),
#  ('ocean', 627),
#  ('stunning', 622),
#  ('pad', 618),
#  ('bay', 615),
#  ('north', 612),
#  ('inner', 605),
#  ('mins', 577),
#  ('lovely', 571),
#  ('station', 554),
#  ('flat', 551),
#  ('perfect', 550),
#  ('beachside', 546),
#  ('ensuite', 534),
#  ('newtown', 526),
#  ('retreat', 513),
#  ('light', 498),
#  ('living', 484),
#  ('w', 481),
#  ('single', 475),
#  ('master', 473),
#  ('style', 457),
#  ('darling', 451),
#  ('art', 449),
#  ('townhouse', 440),
#  ('amazing', 432),
#  ('deco', 424),
#  ('beaches', 421),
#  ('comfortable', 421),
#  ('charming', 408),
#  ('two', 406),
#  ('convenient', 406),
#  ('queen', 402),
#  ('cottage', 396),
#  ('brand', 394),
#  ('clean', 389),
#  ('point', 387),
#  ('penthouse', 377),
#  ('best', 372),
#  ('bronte', 369),
#  ('minutes', 361),
#  ('filled', 358),
#  ('renovated', 353),
#  ('entire', 330),
#  ('designer', 322),
#  ('friendly', 320),
#  ('train', 318)]
